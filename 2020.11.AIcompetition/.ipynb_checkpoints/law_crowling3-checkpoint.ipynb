# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import os

# %%
path = 'D:/Programming/2020.11.AIcompet'

# https://systemtrade.tistory.com/345 << bs 사용법

# %%
driver = webdriver.Ie('D:/Programming/IEDriverServer2.exe')
time.sleep(1)
driver.get('https://www.scourt.go.kr/portal/information/finalruling/peruse/peruse_status.jsp')
time.sleep(1)

iframes = driver.find_elements_by_tag_name('iframe')
print('현재 페이지에 iframe은 %d개가 있습니다.' % len(iframes))
driver.switch_to.frame(iframes[0])

driver.find_element_by_xpath('''//input[@id='accept']''').click()
time.sleep(1)
driver.find_element_by_xpath('''//input[@id='name']''').send_keys('박동주')
time.sleep(1)
driver.find_element_by_xpath('''//input[@id='jumin1']''').send_keys('비밀>.<')
time.sleep(1)
driver.find_element_by_xpath('''//input[@id='jumin2']''').send_keys('비밀2>.<')
time.sleep(1)
driver.find_element_by_xpath('''//img[@id='auth']''').click()
time.sleep(1)
driver.find_element_by_xpath('''//a[@id='tb2']''').click()
time.sleep(1)
driver.find_element_by_xpath('''//img[@id='endDayBtn']''').click()
time.sleep(1)
driver.find_element_by_xpath('''//input[@id='eDate']''').send_keys('20181114')
time.sleep(1)
driver.find_element_by_xpath('''//img[@id='startDayBtn']''').click()
time.sleep(1)
driver.find_element_by_xpath('''//input[@id='sDate']''').send_keys('20161115')
time.sleep(1)
driver.find_element_by_xpath('''//input[@id='mq']''').send_keys('폭행 | 폭력')
time.sleep(1)
driver.find_element_by_xpath('''//input[@id='msearch-button']''').click()
time.sleep(1)
driver.find_element_by_xpath('''//select[@id='viewlist']''').click()
time.sleep(1)
driver.find_element_by_xpath('''//select[@id='viewlist']/option[@value='50']''').click()
time.sleep(1)
driver.find_element_by_xpath('''//dd[@class='btn']/img[@onclick='view()']''').click()
time.sleep(1)

soup = BeautifulSoup(driver.page_source, 'html.parser')
alist = []
blist = []

for n,i in enumerate(soup.find_all('td')):
    j = i.get_text()
    j = " ".join(j.split())
    alist.append(j)
    if ((n+1) % 6) == 0:
        blist.append(alist)
        alist = []

num = 2

while num < 83:
    
    path = '''//a[@onclick="javascript:mdetail_search('{}');"]'''.format(num)
    
    if driver.find_element_by_xpath(path):
        driver.find_element_by_xpath(path).click()
        time.sleep(1)
        soup = BeautifulSoup(driver.page_source, 'html.parser')

        if soup.find('tr',{'class':'disable2'}):
            soup.find('tr',{'class':'disable2'}).decompose()

        for n,i in enumerate(soup.find_all('td')):
            j = i.get_text()
            j = " ".join(j.split())
            alist.append(j)
            if ((n+1) % 6) == 0:
                blist.append(alist)
                alist = []
        num = num + 1
        
    else:
        continue
    
df = pd.DataFrame(blist)
time.sleep(3)
print('완료')
driver.quit()
# Out:
# 현재 페이지에 iframe은 1개가 있습니다.
# 완료

# %%
df[480:520]
# Out:
#     0           1                          2              3  \
# 480    2018.09.12       서울행정법원 [2018구단61935]  난민불인정결···[행정]
# 481    2018.09.12        수원지방법원 [2018구단2791]  영업정지처분···[행정]
# 482    2018.09.12        서울고등법원 [2018누45802]  교장승진임용···[행정]
# 483    2018.09.12      서울북부지방법원 [2018나30762]        위자료[민사]
# 484    2018.09.12   수원지방법원 여주지원 [2018가단1713]       점포인도[민사]
# 485    2018.09.12      서울중앙지방법원 [2017나79860]        구상금[민사]
# 486    2018.09.12        울산지방법원 [2017가단9984]  손해배상(기···[민사]
# 487    2018.09.12        창원지방법원 [2017가단8312]        대여금[민사]
# 488    2018.09.12      대전지방법원 [2016가합107299]  손해배상(기···[민사]
# 489    2018.09.11       수원지방법원 [2018구합64673]  출석정지 2···[행정]
# 490    2018.09.11        춘천지방법원 [2018구합5169]  자동차운전면···[행정]
# 491  ... 비해 여성의 사회참여도가 높은 편이며, 가정폭력에 대한 형사처벌도 이루어지고...
# 492  .... (원고는 이 사건 처분 이후 위 특수폭행의 형사재판이 항소심에서 벌금 50...
# 493  .... 청구원인에 관한 판단 원고는, C와 D을 폭력행위등처벌에관한법률위반(공동협...
# 494  ... 없는 치관 파절 등의 상해를 입었다. ㉲ 피고는 위 폭력 행사에 대하여 20...
# 495  ... 지지 아니합니다. 다만, 저항할 수 없는 폭력이나 자기 또는 친족의 생명신체...
# 496  ... 합의 하에 성관계를 한 적이 있었고 원고가 폭행, 협박을 하지는 않았다’고 ...
# 497  ... 안면부 등을 수회 때렸다. ㉱ 원고는 피고의 위 폭력 행사로 인하여 치아아탈...
# 498  ... 이유로 원고가 피고를 폭행하여 뇌졸증, 족부... 주먹으로 폭력을 행사하였다...
# 499  .... 위 인정사실에 의하면, 원고들은 피고의 폭행, 모욕 행위로 정신상 고통을 ...
# 500  ... 달리 이를 인정할 증거가 없다. ③ 피고 F의 폭행행위에 관하여 살피건대, ...
# 501  ... 않으며, 상대방에 대하여 폭언이나 폭력 등을 행사하지 않도록 각별히 유의한다...
# 502  ... 근로감독관들이나 피고에게 D로부터 폭행당하였다는 사실을 알리지 않았다. 나)...
# 503  ... 징계 전에도 직원 간 폭행이나 사적 영역에서 발생한 폭력에 관하여도 징계를 ...
# 504  ... 전체의 취지를 종합하면, 원고는 피고의 폭행으로 인한 상해로 2014. 11...
# 505  ... 따라 당사자의 의견을 청취하였으며, 향후 폭력적인 사태가 발생될 가능성이 농...
# 506  1. 처분의 경위 가. 원고는 2000. 3. 1. B초등학교 교사로 임용되어 20...
# 507  1. 처분의 경위 가. 원고는 2012. 11. 12.부터 수원시 영통구 B에서 노...
# 508  1. 처분의 경위 기관명 기관기호 급여종류 설립주체 대표자 B요양원 (2015. 9...
# 509  .... 위 CT진단촬영비 등은 원고 A이 이 사건 폭행으로 인해 입게 된 상해의 ...
# 510  ... 원고 A의 동생인 L의 폭행 사건 및 교사 M의 L 폭행... 6) 이에 F...
# 511  ... 70,000,000원을 횡령하였고, 2012. 9.경 I을 폭행하였다’는 범...
# 512  ... 남성으로부터 성폭행을 당하였다. 이후... 마을을 떠나라며 폭력을 행사하였다...
# 513  ... 이유에 관하여 가해자들이 원고의 부모를 폭행하고, 원고의 동생을 집으로 끌고...
# 514  ... 주의하여 주시기 바랍니다. 2015. 9. 18. 언어폭력, 성희롱, 치료시...
# 515  .... 5. 10.경 원고에게 위 1. 나.항 및 다.항 기재 폭행 등 당시까지 ...
# 516  ... 시킨 채 수업장소를 이탈하였다. ⑤ 교직원 폭행 2016. 5. 9. 교직원...
# 517  1. 처분의 경위 가. 원고는 2002. 7. 1. 초등학교 교사로 임용되었고 20...
# 518  ... 변론 전체의 취지를 종합하면, 원고가 위 폭행으로 인하여 치료비 192,85...
# 519  ... 2012. 3. 7. ‘A 이 자식은 돈, 여자, 폭행과 관련하여 매우 지저...

# %%
df.rename(columns={0:'공백', 1:'선고일자',2:'법원명과 사건번호', 3:'사건명', 4:'주문', 5:'이유'}, inplace=True)
df.drop(columns='공백', inplace=True)
df.head()
# Out:
#          선고일자             법원명과 사건번호            사건명  \
# 0  2018.11.14  서울행정법원 [2018구단66206]  난민불인정결···[행정]
# 1  2018.11.14  서울행정법원 [2018구단19026]  난민불인정결···[행정]
# 2  2018.11.14   인천지방법원 [2018나60451]  손해배상(기···[민사]
# 3  2018.11.14   광주고등법원 [2018나22748]     해고무효확인[민사]
# 4  2018.11.14   대구고등법원 [2018나22313]     해고무효확인[민사]
#
#                                                   주문  \
# 0                1. 원고의 청구를 기각한다. 2. 소송비용은 원고가 부담한다.
# 1                1. 원고의 청구를 기각한다. 2. 소송비용은 원고가 부담한다.
# 2  1. 원고의 피고들에 대한 항소를 모두 기각한다. 2. 항소비용은 원고가 부담한다....
# 3  1. 피고의 항소를 기각한다. 2. 항소비용은 피고가 부담한다. 청구취지 및 항소취...
# 4  1. 원고의 항소를 기각한다. 2. 항소비용은 원고가 부담한다. 청구취지 및 항소취...
#
#                                                   이유
# 0  ... 요금 지불을 요구하며 항의한 원고를 폭행하였고, 그 후에도 계속하여 원고를 ...
# 1  ... 상납하지 않는다는 이유로 원고를 다시 폭행하여 허벅지 골절상을 입혔다. 이러...
# 2  ..., 원고는 2017. 6. 30. 19:50경 피고들로부터 폭행당한 사실(이하...
# 3  ... C이 개인적으로 마련한 자리이고, 이 사건 폭행행위도 이성 문제에 관한 오해...
# 4  ... 근무하였다. 나. 피고 대학 성희롱성폭력 대책위원회(이하 ‘대책위원회’라고....

# %%
df.to_csv('law_crawling40.csv', sep=',', na_rep='NaN', encoding='utf-8')

# %%
tq = pd.read_csv("D:/Programming/2020.11.AIcompet/law_crawling41.csv", sep=",", encoding="CP949")
tq.head()
# Out:
#    Unnamed: 0   0           1                     2              3  \
# 0           0 NaN  2018.11.14  서울행정법원 [2018구단66206]  난민불인정결···[행정]
# 1           1 NaN  2018.11.14  서울행정법원 [2018구단19026]  난민불인정결···[행정]
# 2           2 NaN  2018.11.14   인천지방법원 [2018나60451]  손해배상(기···[민사]
# 3           3 NaN  2018.11.14   광주고등법원 [2018나22748]     해고무효확인[민사]
# 4           4 NaN  2018.11.14   대구고등법원 [2018나22313]     해고무효확인[민사]
#
#                                                    4  \
# 0                1. 원고의 청구를 기각한다. 2. 소송비용은 원고가 부담한다.
# 1                1. 원고의 청구를 기각한다. 2. 소송비용은 원고가 부담한다.
# 2  1. 원고의 피고들에 대한 항소를 모두 기각한다. 2. 항소비용은 원고가 부담한다....
# 3  1. 피고의 항소를 기각한다. 2. 항소비용은 피고가 부담한다. 청구취지 및 항소취...
# 4  1. 원고의 항소를 기각한다. 2. 항소비용은 원고가 부담한다. 청구취지 및 항소취...
#
#                                                    5
# 0  ... 요금 지불을 요구하며 항의한 원고를 폭행하였고, 그 후에도 계속하여 원고를 ...
# 1  ... 상납하지 않는다는 이유로 원고를 다시 폭행하여 허벅지 골절상을 입혔다. 이러...
# 2  ..., 원고는 2017. 6. 30. 19:50경 피고들로부터 폭행당한 사실(이하...
# 3  ... C이 개인적으로 마련한 자리이고, 이 사건 폭행행위도 이성 문제에 관한 오해...
# 4  ... 근무하였다. 나. 피고 대학 성희롱성폭력 대책위원회(이하 ‘대책위원회’라고....
